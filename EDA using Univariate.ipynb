# %%
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 59           951         1       1
# 168         1060         1       1
# 404         1296         0       1
# 395         1287         1       1
# 195         1087         0       3
# 131         1023         0       1
# 150         1042         1       1
# 285         1177         0       3
# 222         1114         1       2
# 242         1134         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 168  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  female   NaN      0
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0      1
# 195                  Karlsson, Mr. Julius Konrad Eugen    male  33.0      0
# 131                          Gracie, Col. Archibald IV    male  53.0      0
# 150              Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 285                                Dennis, Mr. William    male  36.0      0
# 222                         Cook, Mrs. (Selena Rogers)  female  22.0      0
# 242                       Spedden, Mr. Frederic Oakley    male  45.0      1
#
#      Parch       Ticket      Fare Cabin Embarked
# 59       0     PC 17608  262.3750   B61        C
# 168      0        17770   27.7208   NaN        C
# 404      0        17765   27.7208   D40        C
# 395      0        13695   60.0000   C31        S
# 195      0       347465    7.8542   NaN        S
# 131      0       113780   28.5000   C51        C
# 150      1        11767   83.1583   C54        C
# 285      0    A/5 21175    7.2500   NaN        S
# 222      0  W./C. 14266   10.5000   F33        S
# 242      1        16966  134.5000   E34        C

# %% [markdown]
# # Categorical Data

# %% [markdown]
# ## Countplot

# %%
sns.countplot(x="Survived",data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x="Pclass",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df["Fare"].describe()
# Out:
# count    417.000000
# mean      35.627188
# std       55.907576
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.500000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# # pieChart

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%2.f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"],bins=50)
# Out:
# (array([ 8.,  3.,  0.,  4.,  1.,  4.,  2.,  3.,  3.,  4.,  2., 20.,  7.,
#         25., 17., 28., 11., 25.,  8., 25., 12.,  8.,  7., 10.,  6.,  7.,
#         11.,  5.,  5.,  9.,  8.,  5.,  8.,  1.,  3.,  2.,  6.,  3.,  2.,
#          4.,  3.,  2.,  3.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.17  ,  1.6866,  3.2032,  4.7198,  6.2364,  7.753 ,  9.2696,
#         10.7862, 12.3028, 13.8194, 15.336 , 16.8526, 18.3692, 19.8858,
#         21.4024, 22.919 , 24.4356, 25.9522, 27.4688, 28.9854, 30.502 ,
#         32.0186, 33.5352, 35.0518, 36.5684, 38.085 , 39.6016, 41.1182,
#         42.6348, 44.1514, 45.668 , 47.1846, 48.7012, 50.2178, 51.7344,
#         53.251 , 54.7676, 56.2842, 57.8008, 59.3174, 60.834 , 62.3506,
#         63.8672, 65.3838, 66.9004, 68.417 , 69.9336, 71.4502, 72.9668,
#         74.4834, 76.    ]),
#  <BarContainer object of 50 artists>)

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_26284\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot([df["Age"]])
# Out:
# <Axes: >

# %%
df2=pd.read_csv("world_university_survey_dataset.csv")

# %%
df2.sample(10)
# Out:
#      student_id      student_name  age  gender      country  \
# 388         389     Brian Sanchez   26  Female        India
# 253         254       Scott Ayers   28    Male     Malaysia
# 708         709   Melinda Mahoney   26  Female           UK
# 392         393      Bill Johnson   30    Male          USA
# 894         895     Eric Marshall   22   Other          USA
# 36           37      Edward Singh   33  Female        Japan
# 645         646     Brandon Brown   32    Male     Pakistan
# 244         245  Michael Oconnell   20    Male  Netherlands
# 998         999         Ryan Cook   20  Female        India
# 842         843   Christian Brown   34   Other    Australia
#
#                                  university program_level    field_of_study  \
# 388             Sanchez-Harrison University      Bachelor  Computer Science
# 253                  Robbins PLC University           PhD       Engineering
# 708                 Mckinney LLC University           PhD                AI
# 392                   Martin Ltd University      Bachelor                AI
# 894               Davis and Sons University      Bachelor              Arts
# 36                    Cox-Sutton University           PhD      Data Science
# 645  Mendoza, Martin and Navarro University        Master          Business
# 244                  Simpson PLC University           PhD       Engineering
# 998                 Chaney-Chang University        Master          Medicine
# 842    Parker, Burgess and Davis University        Master           Physics
#
#      year_of_study  tuition_usd scholarship online_classes  \
# 388              4         8918         Yes            Yes
# 253              2        32360         Yes             No
# 708              2        25141          No             No
# 392              2         3723         Yes            Yes
# 894              5        18114         Yes            Yes
# 36               3        22168         Yes            Yes
# 645              4        34380          No            Yes
# 244              4        21804         Yes             No
# 998              4        18349         Yes            Yes
# 842              3        49775          No            Yes
#
#      campus_facilities_rating  teaching_quality_rating overall_satisfaction
# 388                         1                        4       Very Satisfied
# 253                         5                        1       Very Satisfied
# 708                         4                        2       Very Satisfied
# 392                         2                        1    Very Dissatisfied
# 894                         1                        5       Very Satisfied
# 36                          1                        5         Dissatisfied
# 645                         5                        2       Very Satisfied
# 244                         4                        5              Neutral
# 998                         2                        2       Very Satisfied
# 842                         5                        1       Very Satisfied

# %%
plt.hist(df2["age"])
# Out:
# (array([ 99., 100., 100., 116.,  52., 103.,  95., 109., 118., 108.]),
#  array([17. , 18.8, 20.6, 22.4, 24.2, 26. , 27.8, 29.6, 31.4, 33.2, 35. ]),
#  <BarContainer object of 10 artists>)

# %%
df2["field_of_study"].describe()
# Out:
# count                 1000
# unique                  10
# top       Computer Science
# freq                   119
# Name: field_of_study, dtype: object

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)
