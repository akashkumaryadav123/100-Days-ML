# %%
import pandas as pd 
df=pd.read_csv("Used_Bikes.csv")

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file="report.html")
# Out:
# Summarize dataset:   0%| | 0/13 [00:00<?, ?it/s, Describe varia
# Summarize dataset:  46%|▍| 6/13 [00:00<00:01,  3.56it/s, Descri
# 100%|████████████████████████████| 8/8 [00:00<00:00, 31.71it/s]
# Summarize dataset: 100%|█| 33/33 [00:05<00:00,  6.08it/s, Compl
# Generate report structure: 100%|█| 1/1 [00:04<00:00,  4.58s/it]
# Render HTML: 100%|███████████████| 1/1 [00:00<00:00,  1.57it/s]
# Export report to file: 100%|█████| 1/1 [00:00<00:00, 47.54it/s]
