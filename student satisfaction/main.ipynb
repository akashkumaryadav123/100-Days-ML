# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("world_university_survey_dataset.csv",index_col=0)

# %%
df

# %%
plt.hist(df["gender"])
# Out:
# (array([342.,   0.,   0.,   0.,   0., 301.,   0.,   0.,   0., 357.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
india_data = df[df["country"] == "India"]

# %%
india_data.sample(20)

# %%
india_data["gender"].value_counts().plot(kind="pie",autopct="%2.f")

# %%
import requests

# %%
resp = requests.get("https://nekos.best/api/v2/neko")
data = resp.json()

# %%
data
# Out:
# {'results': [{'artist_name': 'ni-nya',
#    'artist_href': 'https://www.pixiv.net/en/users/56113858',
#    'source_url': 'https://www.pixiv.net/en/artworks/133331272',
#    'url': 'https://nekos.best/api/v2/neko/1631782f-7751-46cc-9947-ae7aeda740bd.png'}]}
